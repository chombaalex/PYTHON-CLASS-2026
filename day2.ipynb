# %%
print("alex chomba")
print("ugali","swimming")
print("************************")
print("welcome to python class!")
print("************************")
# Out:
# alex chomba
# ugali swimming
# ************************
# welcome to python class!
# ************************

# %%
print("my name is Alex chomba")
print("i am 20 Years old")
print("i live in kenya")
print("i want to learn programming to build mobile apps")
# Out:
# my name is Alex chomba
# i am 20 Years old
# i live in kenya
# i want to learn programming to build mobile apps

# %%
print(5+3)
print(10-4)
print(4*3)
print(10/2)

num1=14
num2=16
sumresult=num1+num2
print(sumresult)
sub=num1-num2
print(sub)
multiply=num1*num2
print(multiply)
div=num1/num2
print(div)
# Out:
# 8
# 6
# 12
# 5.0
# 30
# -2
# 224
# 0.875

# %%
age=20
doy=365
dayold=age*doy
print(f"you are {dayold} old")
# Out:
# you are 7300 old

# %%
Name="Alex chomba"
Age=20
Location="kenya"
goal="i want to learn programming to build mobile apps"
#comment
print(f"my name is {Name},i am {Age} years old,i live in{Location}and {goal}")
# Out:
# my name is Alex chomba,i am 20 years old,i live inkenyaand i want to learn programming to build mobile apps

# %%
name=input("Enter your name? ")
age=int(input("how old are you? "))
location=input("where a you from? ")
print(f"welcome to our company {name} your are {age} years old and you come from {location}")
print("welcome", name,"you are", age)
print("welcome "+ name+"you are")
# Out:
# Enter your name? alex
# how old are you? 26
# where a you from? kenya
# welcome to our company alex your are 26 years old and you come from kenya
# welcome alex you are 26
# welcomealexyou are
