# %% [markdown]
# MY FIRST PROJECT

# %%
print("alex chomba")
# Out:
# alex chomba

# %% [markdown]
# Additions

# %%
print("1*4")
print(1*4)
# Out:
# 1*4
# 4

# %%
year=2026
print(type(year))
print(year)
name="alex"
print(type(name))
print(name)
name="jane"
print(name)
# Out:
# <class 'int'>
# 2026
# <class 'str'>
# alex
# jane

# %% [markdown]
# variables

# %%
print(name,year)
print("name,year")
# Out:
# jane 2026
# name,year
